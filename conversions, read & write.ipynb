# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\CSVDATAFILE.csv")

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country     Sales  Quantity  Discount    Profit  Shipping Cost  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_txt("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTAMPERSANDDATAFILE.txt")
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_txt("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTAMPERSANDDATAFILE.txt")
#       2 df.head()
#
# File ~\ANACONDA\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_txt'

# %%
import pandas as pd

read_file = pd.read_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTAMPERSANDDATAFILE.txt")
read_file.to_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTAMPERSANDDATAFILE.csv", index=None)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df =pd.read_csv("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.pdf")

# %%
df.head()
# Out:
#   Row ID;Order ID;Order Date;Ship Date;Ship Mode;Customer ID;Customer Name;Segment;City;State;Country;Sales;Quantity;Discount;Profit;Shipping Cost;Order Priority
# 0  32298;CA-2012-124891;31-07-2012;31-07-2012;Sam...
# 1  26341;IN-2013-77878;05-02-2013;07-02-2013;Seco...
# 2  25330;IN-2013-71249;17-10-2013;18-10-2013;Firs...
# 3  13524;ES-2013-1579342;28-01-2013;30-01-2013;Fi...
# 4  47221;SG-2013-4320;05-11-2013;06-11-2013;Same ...

# %%
import pandas as pd

read_file = pd.read_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.pdf")
read_file.to_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.csv", index=None)

# %%
import pandas as pd

read_file = pd.read_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\XMLDATAFILE.xml")
read_file.to_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\XMLDATAFILE.csv", index=None)

# %%
import pandas as pd

read_file = pd.read_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\JSONDATAFILE.json")
read_file.to_csv ("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\JSONDATAFILE.csv", index=None)

# %%
import pandas as pd
df = pd.read_json("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\JSONDATAFILE.json")
df.head()
# Out:
#    ID      Name  Salary   StartDate        Dept
# 0   1      Rick  623.30    1/1/2012          IT
# 1   2       Dan  515.20   9/23/2013  Operations
# 2   3  Michelle  611.00  11/15/2014          IT
# 3   4      Ryan  729.00   5/11/2014          HR
# 4   5      Gary  843.25   3/27/2015     Finance

# %%
import pandas as pd
df = pd.read_xml("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\XMLDATAFILE.xml")
df.head()
# Out:
#    ID      NAME  SALARY   STARTDATE        DEPT
# 0   1      Rick  623.30    1/1/2012          IT
# 1   2       Dan  515.20   9/23/2013  Operations
# 2   3  Michelle  611.00  11/15/2014          IT
# 3   4      Ryan  729.00   5/11/2014          HR
# 4   5      Gary  843.25   3/27/2015     Finance

# %%
import tabula as tb
df = tb.read_pdf("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.pdf")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 import tabula as tb
# ----> 2 df = tb.read_pdf("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.pdf")
#       3 print(df)
#
# AttributeError: module 'tabula' has no attribute 'read_pdf'

# %%
from tabula import convert_into
table_file = r"C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.pdf"
output_csv = r"C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.csv"
df = convert_into(table_file, output_csv, output_format='csv', lattice=True, stream=False, pages="all")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from tabula import convert_into
#       2 table_file = r"C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.pdf"
#       3 output_csv = r"C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\PDFDATAFILE.csv"
#
# ImportError: cannot import name 'convert_into' from 'tabula' (C:\Users\ramya\ANACONDA\Lib\site-packages\tabula\__init__.py)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.to_csv("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTAMPERSANDDATAFILE.txt", sep='$')

# %%
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]], 
index=[1, 2, 3], 
columns=['a', 'b', 'c'])

# %%
print(df)
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\EXCELDATAFILE.xlsx")
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country     Sales  Quantity  Discount    Profit  Shipping Cost  \
# ...

# %%
import pandas as pd
df = pd.read_xml("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\XMLDATAFILE.xml")
df.head()
# Out:
#    ID      NAME  SALARY   STARTDATE        DEPT
# 0   1      Rick  623.30    1/1/2012          IT
# 1   2       Dan  515.20   9/23/2013  Operations
# 2   3  Michelle  611.00  11/15/2014          IT
# 3   4      Ryan  729.00   5/11/2014          HR
# 4   5      Gary  843.25   3/27/2015     Finance

# %%
f = open("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTDATAFILE.txt") 
lines = f.read()
print(lines)
f.close()
# Out:
# ï»¿Row ID,Order ID,Order Date,Ship Date,Ship Mode,Customer ID,Customer Name,Segment,City,State,Country,Sales,Quantity,Discount,Profit,Shipping Cost,Order Priority
# 32298,CA-2012-124891,31-07-2012,31-07-2012,Same Day,RH-19495,Rick Hansen,Consumer,New York City,New York,United States,2309.65,7,0,762.1845,933.57,Critical
# 26341,IN-2013-77878,05-02-2013,07-02-2013,Second Class,JR-16210,Justin Ritter,Corporate,Wollongong,New South Wales,Australia,3709.395,9,0.1,-288.765,923.63,Critical
# 25330,IN-2013-71249,17-10-2013,18-10-2013,First Class,CR-12730,Craig Reiter,Consumer,Brisbane,Queensland,Australia,5175.171,9,0.1,919.971,915.49,Medium
# 13524,ES-2013-1579342,28-01-2013,30-01-2013,First Class,KM-16375,Katherine Murray,Home Office,Berlin,Berlin,Germany,2892.51,5,0.1,-96.54,910.16,Medium
# 47221,SG-2013-4320,05-11-2013,06-11-2013,Same Day,RH-9495,Rick Hansen,Consumer,Dakar,Dakar,Senegal,2832.96,8,0,311.52,903.04,Critical
# ...

# %%
f = open("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTDATAFILE.txt") # opening a file
line1 = f.readline() # reading a line
print(line1)  #'This is the first line. \n'

line2 = f.readline() # reading a line
print(line2)  #'This is the second line.\n'

line3 = f.readline() # reading a line
print(line3)  #'This is the third line.'

line4 = f.readline() # reading a line
print(line4)  #''

f.close() # closing file object
# Out:
# ï»¿Row ID,Order ID,Order Date,Ship Date,Ship Mode,Customer ID,Customer Name,Segment,City,State,Country,Sales,Quantity,Discount,Profit,Shipping Cost,Order Priority
#
# 32298,CA-2012-124891,31-07-2012,31-07-2012,Same Day,RH-19495,Rick Hansen,Consumer,New York City,New York,United States,2309.65,7,0,762.1845,933.57,Critical
#
# 26341,IN-2013-77878,05-02-2013,07-02-2013,Second Class,JR-16210,Justin Ritter,Corporate,Wollongong,New South Wales,Australia,3709.395,9,0.1,-288.765,923.63,Critical
#
# 25330,IN-2013-71249,17-10-2013,18-10-2013,First Class,CR-12730,Craig Reiter,Consumer,Brisbane,Queensland,Australia,5175.171,9,0.1,919.971,915.49,Medium

# %%
f = open("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTDATAFILE.txt",'w')
f.write("Hello") # writing to file
f.close()

# %%
# reading file
f = open("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\TXTDATAFILE.txt",'r') 
f.read()  #'Hello'
f.close()

# %%
import pandas as pd

# %%
df=pd.read_json("C:\\Users\\ramya\\OneDrive\\Desktop\\DATA FILE FORMATS\\JSONDATAFILE.json")

# %%
df.head()
# Out:
#    ID      Name  Salary   StartDate        Dept
# 0   1      Rick  623.30    1/1/2012          IT
# 1   2       Dan  515.20   9/23/2013  Operations
# 2   3  Michelle  611.00  11/15/2014          IT
# 3   4      Ryan  729.00   5/11/2014          HR
# 4   5      Gary  843.25   3/27/2015     Finance

# %%
import matplotlib as plt
