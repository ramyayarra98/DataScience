# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import os
import glob
for dirname, _, filenames in os.walk('D:\\DATA SCIENCE\\PROJECTS\\Car_Licence_Plate_DataSets\\annotations'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars0.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars1.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars10.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars100.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars101.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars102.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars103.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars104.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars105.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars106.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars107.xml
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations\Cars108.xml
# ...

# %%
DATASET_PATH = "D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets"
ANNOTATIONS_PATH = os.path.join(DATASET_PATH, "annotations")
IMAGES_PATH = os.path.join(DATASET_PATH, "images")

print(ANNOTATIONS_PATH)
print(IMAGES_PATH)
# Out:
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\annotations
# D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\images

# %%
image_filename = 'Cars129.png'
image_path = os.path.join(IMAGES_PATH, image_filename)
img = plt.imread(image_path)
fig, ax = plt.subplots(figsize=(10, 8))
ax.imshow(img);
print('Image shape: {}'.format(img.shape))
# Out:
# Image shape: (398, 530, 3)

# %%
with open(os.path.join(ANNOTATIONS_PATH, 'Cars129.xml')) as f:
    print(f.read())
# Out:
# <annotation>
#     <folder>images</folder>
#     <filename>Cars129.png</filename>
#     <size>
#         <width>530</width>
#         <height>398</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>licence</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>204</xmin>
#             <ymin>213</ymin>
#             <xmax>282</xmax>
#             <ymax>267</ymax>
#         </bndbox>
#     </object>
# </annotation>

# %%
from PIL import Image
img = Image.open("D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\images\Cars129.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x398>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from PIL import Image

img=Image.open("D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\images\Cars129.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x398>

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd="C:\\Program Files\\Tesseract-OCR"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 pytesseract.pytesseract.tesseract_cmd="C:\\Program Files\\Tesseract-OCR"
#
# AttributeError: module 'pytesseract.pytesseract' has no attribute 'pytesseract'

# %%
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=530x398 at 0x1DD58840510>

# %%
Vehicle_Number = pytesseract.image_to_string(img)

# %%
print(Vehicle_Number)

# %%
from PIL import Image
from pytesseract import pytesseract
pytesseract = 'C:\Program Files\Tesseract-OCR\tesseract.exe'
img = Image.open(r"D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\images\Cars129.png")
text = pytesseract.image_to_string(img)
print(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 5
#       3 pytesseract = 'C:\Program Files\Tesseract-OCR\tesseract.exe'
#       4 img = Image.open(r"D:\DATA SCIENCE\PROJECTS\Car_Licence_Plate_DataSets\images\Cars129.png")
# ----> 5 text = pytesseract.image_to_string(img)
#       6 print(text)
#
# AttributeError: 'str' object has no attribute 'image_to_string'
